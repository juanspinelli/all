# %%
import requests
from bs4 import *
import json
import pandas as pd
from IPython.display import Image, display, Markdown
import glob

url = 'https://www.ranker.com/list/most-disturbing-thanos-comics/zack-howe'
path_file_dest = r'thanos.json'

def write_doc_json(content, mode):
    own_file = open(path_file_dest, mode, encoding='utf-8')
    own_file.write(content.decode('utf-8'))
    own_file.close()
    print('\n•  El archivo json fue sobre-escrito con exito!')

urls = []
for x in range(1, 5):
    urls.append(url + '?page=' + str(x))
    
thanos = []

for x in urls:
    
    response = requests.get(x, headers={'User-Agent': 'Mozilla/5.0 (Platform; Security; OS-or-CPU; Localization; rv:1.4) Gecko/20030624 Netscape/7.1 (ax)'})
    
    if response.status_code == 200:
        
        soup = BeautifulSoup(response.text, "html.parser")
        title = soup.find_all('span', {'class': 'listItem__h2Link'})
        img = soup.find_all('img', {'class' : 'listItem__image listItem__image--blog'})
        text = soup.find_all('meta', {'itemprop' : 'description'})
        

        for i in range (0, len(title)):
            
            info = {'title' : title[i].get_text(), 
                    'img' : img[i]['src'],
                    'text' : text[i]['content']
                   }
            
            thanos.append(info)
        
    else:
        
        print('Error al conectar a la direccion: ' + str(x))

content = json.dumps(thanos, indent=4, sort_keys=True, ensure_ascii=False).encode('utf-8')
write_doc_json(content ,'w+')
data = pd.read_json(path_file_dest, encoding = 'UTF-8')

print('•  Se leyo el json y se creo el dataframe data')

data.head()
# Out:
# •  El archivo json fue sobre-escrito con exito!
# •  Se leyo el json y se creo el dataframe data
#                                                  img  \
# 0  https://imgix.ranker.com/user_node_img/50082/1...
# 1  https://imgix.ranker.com/user_node_img/50082/1...
# 2  https://imgix.ranker.com/user_node_img/50082/1...
# 3  https://imgix.ranker.com/user_node_img/50082/1...
# 4  https://imgix.ranker.com/user_node_img/50082/1...
#
#                                                 text  \
# 0  In case you were wondering, the sound a head m...
# 1  Thanos was separated from his mother, Sui-San,...
# 2  Infinity Gauntlet put Earth's Mightiest Heroes...
# 3  Thanos's father, the Mentor, is an Eternal. Th...
# 4  The Infinity Gauntlet sees Thanos wreak havoc ...
#
#                                            title
# 0  Thanos Smashes Sam Wilson's Head In His Hands
# 1                 Thanos Dissects His Own Mother
# 2      Thanos's Lackey Beats Spider-Man To Death
# 3              Thanos Punches Through His Father
# 4  Thanos Turns Nebula Into A 'Living Sculpture'

# %%
k = 1
for x in range (0, data.shape[0]):
    name_image_folder = 'thanosImg/' + str(k) + '.jpg'
    image = requests.get(data.img[x]).content
            
    with open(name_image_folder, 'wb') as handler:
            handler.write(image)
    k += 1
    
class bcolors:
    BOLD = '\033[1m'
    ENDC = '\033[0m'

imgs =len(glob.glob("thanosImg/*.jpg"))

listOfImageNames = []

for x in range(1, imgs + 1):
    listOfImageNames.append('thanosImg/' + str(x) + '.jpg')

k = 0

for imageName in listOfImageNames:
    print('\n' * 2)
    print(bcolors.BOLD + data.title[k] + bcolors.ENDC)
    print('')
    print(data.text[k])
    print('')
    display(Image(filename=imageName))
    k += 1
# Out:
# Thanos Smashes Sam Wilson's Head In His Hands
#
# In case you were wondering, the sound a head makes when it is squished between two massive hands is "SPLORT." At least, that's how the gruesome death is depicted in Thanos #10 when the Mad Titan kills ...
# Thanos Dissects His Own Mother
#
# Thanos was separated from his mother, Sui-San, as an infant after she sensed the evil inside him and attempted to kill him. They did not reunite until Thanos was a full-grown adult, and as we learn in his 2013 run, ...
# Thanos's Lackey Beats Spider-Man To Death
#
# Infinity Gauntlet put Earth's Mightiest Heroes through hell, especially Spidey, who was brutally murdered by one of Thanos's henchmen. When the Avengers take on the Mad Titan, Terraxia assists her boss by ...
# Thanos Punches Through His Father
#
# Thanos's father, the Mentor, is an Eternal. Thanos comics that started in 2016 features all kinds of depravity. One such instance is when he murders his father. Thanos is dying from a disease, so he ...
# Thanos Turns Nebula Into A 'Living Sculpture'
#
# The Infinity Gauntlet sees Thanos wreak havoc on pretty much everyone in the Marvel universe. He inflicts the most pain on his self-proclaimed granddaughter, Nebula. When the space pirate makes this claim of relation ...
# Thanos Turns Deadpool Into A Puddle
#
# A big part of Deadpool's whole shtick is the grisly humor he has concerning the creative ways his enemies tear him to shreds. Fortunately, he is able to survive most of these beatings due to his healing abilities. Not even ...
# Thanos Makes Hulk His Leashed Dog
#
# The Thanos comic that began in 2016 goes to some pretty wild places, including a distant future in which Thanos is king of the universe after defeating the Avengers. Most of those Avengers are dead, but not Bruce Banner. He ...
# Thanos Puts Cyclops In A Block And Suffocates Him To Death
#
# As half the people in the universe were killed during the Infinity Gauntlet arc, it should come as no surprise that some of them were heroes. In a fight where Thor is turned to glass, Wolverine has his bones ...
# Thanos Kills Gamora After Raising Her
#
# It's already messed up Thanos took a baby Gamora and raised her to be his personal assassin; murdering said adopted daughter is just overkill. Yet that's precisely what the Mad Titan does in Infinity Watch. When her ...
# Thanos's Mother Tried To Kill Him As An Infant
#
# Thanos's mother, the Eternal Sui-San, saw "death in its eyes" when she first held her newborn son. She wasn't wrong. Unfortunately, she was too prescient for her own good; no one else saw the evil lurking in the baby ...
# Thanos Kills Half The Universe With A Literal Snap Of His Finger
#
# The Infinitely Gauntlet is one of the most devastating weapons in the Marvel universe When all the Infinity Stones (or Soul Gems, originally) are collected and placed in the Gauntlet, the wielder becomes ...
# Thanos Kills War Machine And She-Hulk
#
# Thanos kills a lot of people, so not every murder earns a spot among his most disturbing moments. But since he got a twofer with War Machine and She-Hulk in Civil War II, this double murder ekes into the running.
# Drax Punches Through Thanos's Chest And Rips Out His Heart
#
# The 2006 cosmic Marvel comic event Annihilation is aptly named, as the whole run is littered with brutally serious deaths. Drax's murder of Thanos, for example, is particularly gruesome. While Thanos is no stranger to fists ...
# Thanos Kills Himself
#
# In the three-part comic book event Infinity, the universe is faced with an even greater threat than Thanos: Annihilus. The Mad Titan has to team up with Adam Warlock to stop the big bad. Things go awry though, and Adam ...
# Thanos's Son Puts Him In A State Of Living Death
#
# Thanos finds himself involved in a lot of patricide, both as the culprit and victim. Considering he also has a tendency towards filicide, it seems fair that one of his sons should take him out. Enter Thane. In Thanos: A ...
