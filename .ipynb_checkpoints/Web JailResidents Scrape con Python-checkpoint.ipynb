# %%
import requests
import urllib.request
import pandas as pd
import re
import json
from bs4 import BeautifulSoup

url = 'https://report.boonecountymo.org/mrcjava/servlet/SH01_MP.I00290s?max_rows=250'
path_file_dest = r'JailResidents.json'
response = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Platform; Security; OS-or-CPU; Localization; rv:1.4) Gecko/20030624 Netscape/7.1 (ax)'})

def write_doc_json(content, mode):
    own_file = open(path_file_dest, mode, encoding='utf-8')
    own_file.write(content.decode('utf-8'))
    own_file.close()
    
if response.status_code == 200:
    
    info = []
    soup = BeautifulSoup(response.text, "html.parser")
    
    odd = soup.findAll('tr', attrs={'class': 'odd'})
    
    even = soup.findAll('tr', attrs={'class': 'even'})
 
    for x in range (1, (len(even) - 1)):
        Last_Name = even[x].find('td', {'data-th': 'Last Name'}).get_text()
        First_Name = even[x].find('td', {'data-th': 'First Name'}).get_text()
        Middle_Name = even[x].find('td', {'data-th': 'Middle Name'}).get_text()
        Sex = even[x].find('td', {'data-th': 'Sex'}).get_text()
        Race = even[x].find('td', {'data-th': 'Race'}).get_text()
        Age = even[x].find('td', {'data-th': 'Age'}).get_text()
        City = even[x].find('td', {'data-th': 'City'}).get_text()
        State = even[x].find('td', {'data-th': 'State'}).get_text()
        
        individuo = {'Apellido' : Last_Name, 
                     'Nombre' : First_Name, 
                     'Segundo Nombre' : Middle_Name,
                     'Sexo' : Sex,
                     'Raza' : Race,
                     'Edad' : Age,
                     'Ciudad' : City,
                     'Estado' : State}
        
        info.append(individuo)

    for x in range (0,len(odd)):
        Last_Name = odd[x].find('td', {'data-th': 'Last Name'}).get_text()
        First_Name = odd[x].find('td', {'data-th': 'First Name'}).get_text()
        Middle_Name = odd[x].find('td', {'data-th': 'Middle Name'}).get_text()
        Sex = odd[x].find('td', {'data-th': 'Sex'}).get_text()
        Race = odd[x].find('td', {'data-th': 'Race'}).get_text()
        Age = odd[x].find('td', {'data-th': 'Age'}).get_text()
        City = odd[x].find('td', {'data-th': 'City'}).get_text()
        State = odd[x].find('td', {'data-th': 'State'}).get_text()
        
        individuo = {'Apellido' : Last_Name, 
                     'Nombre' : First_Name, 
                     'Segundo Nombre' : Middle_Name,
                     'Sexo' : Sex,
                     'Raza' : Race,
                     'Edad' : Age,
                     'Ciudad' : City,
                     'Estado' : State}
        
        info.append(individuo)
        
    content = json.dumps(info, indent=4, sort_keys=True, ensure_ascii=False).encode('utf-8')
    write_doc_json(content ,'w+')
    data = pd.read_json(path_file_dest, encoding = 'UTF-8')
else:
    print('No se pudo conectar')
    
data
# Out:
#         Apellido          Ciudad  Edad Estado      Nombre Raza Segundo Nombre  \
# 0          ACTON        COLUMBIA    27     MO     ANTHONY    B           SEAN
# 1          AKERS        COLUMBIA    21     MO      SYDNEY    W            RAE
# 2     AUTENRIETH        COLUMBIA    48     MO        MARK    W        CHARLES
# 3         BACKES        COLUMBIA    35     MO  CHRISTOFER    W         BRYANT
# 4        BALDWIN       CENTRALIA    33     MO     BRANDON    W        MICHAEL
# 5        BARBOUR          TIPTON    44     MO     RICHARD    W          LEWIS
# 6        BATISTE        ST LOUIS    28     MO      WALTER    B          ALLEN
# 7           BEBE        COLUMBIA    40     MO   RWAJEKARE    B
# 8        BENNETT        COLUMBIA    26     MO     DEVANTE    B        JACJUAN
# 9           BENZ        COLUMBIA    30     MO     WILLIAM    W         ERNEST
# 10          BOND        COLUMBIA    37     MO     DEMITRI    B          LAMAR
# 11        BOSTON        ST LOUIS    24     MO       COREY    B         DESEAN
# 12          BOYD        COLUMBIA    33     MO         LEE    B        DEMAREO
# 13         BROWN      FLORISSANT    32     MO       BARRY    B         RONELL
# 14       BUCKNER        COLUMBIA    19     MO       KEVIN    B        MAURICE
# 15         BURKE     HALLISVILLE    48     MO        JOHN    W        MATTHEW
# 16          BUSH        COLUMBIA    26     MO     MALCOLM    U         DWAYNE
# 17          CAMP           TOANO    33     VA       JERRY    B            LEE
# 18      CANFIELD        COLUMBIA    37     MO      NATHAN    W         EDWARD
# 19        CARTER          FULTON    34     MO       LORAZ    B          WINCE
# 20      CHARTERS        COLUMBIA    35     MO  RECCO EARL    B         DWAYNE
# 21         CLARK        COLUMBIA    45     MO     RICHARD    W          DEREK
# 22         COHEN  JEFFERSON CITY    24     MO        NOAH    B          QIMAR
# 23       COLEMAN      FLORISSANT    22     MO     CAMERON    B  MICHAEL LLOYD
# 24     COMMANDER        COLUMBIA    23     MO     JAVANTE    B          BRUCE
# 25    CORNELISON        COLUMBIA    48     MO       BRIAN    W            LEE
# 26           COX        COLUMBIA    29     MO       JAQUE    B          DERON
# 27       CRAWLEY        COLUMBIA    65     MO       EDDIE    B         HUGHES
# 28   CRUTCHFIELD        COLUMBIA    22     MO        ROMA    B         MARINE
# 29    DANIELSSON  JEFFERSON CITY    24     MO       DYLAN    W          JAMES
# ..           ...             ...   ...    ...         ...  ...            ...
# 219       PRINCE        COLUMBIA    35     MO      MONEKA    B          MARIE
# 220        REESE    KINGDOM CITY    43     MO       SHAWN    W    CHRISTOPHER
# 221     ROBINSON    BLUE SPRINGS    43     MO         JAY    W           PAUL
# 222       ROBLES        COLUMBIA    24     MO     DEMETRI    H        TIMOTHY
# 223      ROTHMAN         LEBANON    18     MO      TRETEN    W           ADAM
# 224       ROWELL      HOLTSUMMIT    48     MO     ANTHONY    W           TODD
# 225       RUFFIN        COLUMBIA    49     MO     CHARLES    B         EDWARD
# 226       SALLEE        COLUMBIA    28     MO     TABITHA    B       LEANETTE
# 227      SANDERS        COLUMBIA    57     MO       DEBRA    W        SUZANNE
# 228       SHEGOG        COLUMBIA    61     MO     ANTHONY    B         LAMARR
# 229       SHOUNE        COLUMBIA    29     MO        SAID    B           JIMA
# 230         SLUE     KANSAS CITY    28     KS      DAMEON    B          BILAL
# 231        SMITH        COLUMBIA    28     MO     DENZELL    B        LAVONTE
# 232        SMITH        COLUMBIA    28     MO      KAELEB    B        ALSHAUN
# 233         SORM        COLUMBIA    33     MO     BRANDIE    W          MARIE
# 234    STAPLETON        COLUMBIA    34     MO     MICHAEL    B         CORTEZ
# 235     STEPHENS        COLUMBIA    38     MO      JOHNNY    W           LYLE
# 236       STOKES        COLUMBIA    59     MO      WILLIS    W         DANIEL
# 237       TAYLOR        COLUMBIA    36     MO        TONI    B         NICOLE
# 238        TOBIN        COLUMBIA    38     MO      ROBERT    W        FRANCIS
# 239      TRIMBLE        COLUMBIA    38     MO        JOHN    W          ALLEN
# 240    TWEEDDALE        COLUMBIA    26     MO       BRYAN    W        MICHAEL
# 241         WADE        COLUMBIA    53     MO        CARL    B         LAVELL
# 242         WALL        COLUMBIA    39     MO      NORRIS    B      JEFFERSON
# 243      WARRICK        COLUMBIA    41     MO      MELVIN    B          ALLEN
# 244       WATERS        ST LOUIS    39     MO     ANTHONY    B        ORTAGUS
# 245    WHITWORTH        COLUMBIA    30     MO     BRENDAN    W           GALE
# 246     WILLIAMS        COLUMBIA    22     MO      DAVEON    B       TRESHAWN
# 247     WILLIAMS        COLUMBIA    28     MO      JESSIE    U        RANDALL
# 248       WILSON        COLUMBIA    17     MO   KNOWLEDGE    B      DEANTHONY
#
#     Sexo
# 0      M
# 1      F
# 2      M
# 3      M
# 4      M
# 5      M
# 6      M
# 7      M
# 8      M
# 9      M
# 10     M
# 11     M
# 12     M
# 13     M
# 14     M
# 15     M
# 16     M
# 17     M
# 18     M
# 19     M
# 20     M
# 21     M
# 22     M
# 23     M
# 24     M
# 25     M
# 26     M
# 27     M
# 28     F
# 29     M
# ..   ...
# 219    F
# 220    M
# 221    M
# 222    M
# 223    M
# 224    M
# 225    M
# 226    F
# 227    F
# 228    M
# 229    M
# 230    M
# 231    M
# 232    M
# 233    F
# 234    M
# 235    M
# 236    M
# 237    F
# 238    M
# 239    M
# 240    M
# 241    M
# 242    M
# 243    M
# 244    M
# 245    M
# 246    M
# 247    M
# 248    M
#
# [249 rows x 8 columns]
